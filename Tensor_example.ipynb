# %%
## **TENSORFLOW WITHOUT KERAS**

https://becominghuman.ai/image-classification-with-tensorflow-2-0-without-keras-e6534adddab2

# %%
#conda update --all
#!pip install tensorflow_datasets
# !pip install --upgrade tensorflow
# Out:
# Requirement already up-to-date: tensorflow in /home/erikapat/anaconda3/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.12.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.1.0,>=2.0.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.33.4)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.1.7)
# Requirement already satisfied, skipping upgrade: tensorboard<2.1.0,>=2.0.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.17.1)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.2.2)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (0.8.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (1.23.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorflow) (3.9.1)
# Requirement already satisfied, skipping upgrade: h5py in /home/erikapat/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow) (2.9.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (41.0.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (0.15.5)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (1.7.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (0.4.1)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (0.2.7)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools<3.2,>=2.0.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.1)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (1.3.0)
# Collecting pyasn1<0.5.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/a1/71/8f0d444e3a74e5640a3d5d967c1c6b015da9c655f35b2d308a55d907a517/pyasn1-0.4.7-py2.py3-none-any.whl (76kB)
#      |████████████████████████████████| 81kB 4.8MB/s eta 0:00:011
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (2.22.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (2019.6.16)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/erikapat/anaconda3/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (1.24.2)
# Installing collected packages: pyasn1
#   Found existing installation: pyasn1 0.4.5
#     Uninstalling pyasn1-0.4.5:
#       Successfully uninstalled pyasn1-0.4.5
# Successfully installed pyasn1-0.4.7

# %% [markdown]
# ## **TENSORFLOW 2.0**

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
padding = "SAME"  #@param ['SAME', 'VALID' ]
num_output_classes = 102  #@param {type: "number"}
batch_size = 32  #@param {type: "number"}
learning_rate = 0.001  #@param {type: "number"}

# %%
dataset_name = 'horses_or_humans'

dataset = tfds.load( name=dataset_name , split=tfds.Split.TRAIN )
dataset = dataset.shuffle( 1024 ).batch( batch_size )

# %% [markdown]
# ## **CNN**

# %% [markdown]
# Remember what we needed for a CNN in Keras:
# * Conv2D,
# * MaxPooling2D,
# * Flatten and
# * Dense layers
#
# We need to create these layers using the tf.nn module.

# %%
leaky_relu_alpha = 0.2
dropout_rate = 0.5

def conv2d( inputs , filters , stride_size ):
    out = tf.nn.conv2d( inputs , filters , strides=[ 1 , stride_size , stride_size , 1 ] , padding=padding ) 
    return tf.nn.leaky_relu( out , alpha=leaky_relu_alpha ) 

def maxpool( inputs , pool_size , stride_size ):
    return tf.nn.max_pool2d( inputs , ksize=[ 1 , pool_size , pool_size , 1 ] , padding='VALID' , strides=[ 1 , stride_size , stride_size , 1 ] )

def dense( inputs , weights ):
    x = tf.nn.leaky_relu( tf.matmul( inputs , weights ) , alpha=leaky_relu_alpha )
    return tf.nn.dropout( x , rate=dropout_rate )

# %%
output_classes = 3
initializer = tf.initializers.glorot_uniform()
def get_weight( shape , name ):
    return tf.Variable( initializer( shape ) , name=name , trainable=True , dtype=tf.float32 )

shapes = [
    [ 3 , 3 , 3 , 16 ] , 
    [ 3 , 3 , 16 , 16 ] , 
    [ 3 , 3 , 16 , 32 ] , 
    [ 3 , 3 , 32 , 32 ] ,
    [ 3 , 3 , 32 , 64 ] , 
    [ 3 , 3 , 64 , 64 ] ,
    [ 3 , 3 , 64 , 128 ] , 
    [ 3 , 3 , 128 , 128 ] ,
    [ 3 , 3 , 128 , 256 ] , 
    [ 3 , 3 , 256 , 256 ] ,
    [ 3 , 3 , 256 , 512 ] , 
    [ 3 , 3 , 512 , 512 ] ,
    [ 8192 , 3600 ] , 
    [ 3600 , 2400 ] ,
    [ 2400 , 1600 ] , 
    [ 1600 , 800 ] ,
    [ 800 , 64 ] ,
    [ 64 , output_classes ] ,
]

weights = []
for i in range( len( shapes ) ):
    weights.append( get_weight( shapes[ i ] , 'weight{}'.format( i ) ) )

# %%
def model( x ) :
    x = tf.cast( x , dtype=tf.float32 )
    c1 = conv2d( x , weights[ 0 ] , stride_size=1 ) 
    c1 = conv2d( c1 , weights[ 1 ] , stride_size=1 ) 
    p1 = maxpool( c1 , pool_size=2 , stride_size=2 )
    
    c2 = conv2d( p1 , weights[ 2 ] , stride_size=1 )
    c2 = conv2d( c2 , weights[ 3 ] , stride_size=1 ) 
    p2 = maxpool( c2 , pool_size=2 , stride_size=2 )
    
    c3 = conv2d( p2 , weights[ 4 ] , stride_size=1 ) 
    c3 = conv2d( c3 , weights[ 5 ] , stride_size=1 ) 
    p3 = maxpool( c3 , pool_size=2 , stride_size=2 )
    
    c4 = conv2d( p3 , weights[ 6 ] , stride_size=1 )
    c4 = conv2d( c4 , weights[ 7 ] , stride_size=1 )
    p4 = maxpool( c4 , pool_size=2 , stride_size=2 )

    c5 = conv2d( p4 , weights[ 8 ] , stride_size=1 )
    c5 = conv2d( c5 , weights[ 9 ] , stride_size=1 )
    p5 = maxpool( c5 , pool_size=2 , stride_size=2 )

    c6 = conv2d( p5 , weights[ 10 ] , stride_size=1 )
    c6 = conv2d( c6 , weights[ 11 ] , stride_size=1 )
    p6 = maxpool( c6 , pool_size=2 , stride_size=2 )

    flatten = tf.reshape( p6 , shape=( tf.shape( p6 )[0] , -1 ))

    d1 = dense( flatten , weights[ 12 ] )
    d2 = dense( d1 , weights[ 13 ] )
    d3 = dense( d2 , weights[ 14 ] )
    d4 = dense( d3 , weights[ 15 ] )
    d5 = dense( d4 , weights[ 16 ] )
    logits = tf.matmul( d5 , weights[ 17 ] )

    return tf.nn.softmax( logits )

# %%
def loss( pred , target ):
    return tf.losses.categorical_crossentropy( target , pred )

optimizer = tf.optimizers.Adam( learning_rate )

def train_step( model, inputs , outputs ):
    with tf.GradientTape() as tape:
        current_loss = loss( model( inputs ), outputs)
    grads = tape.gradient( current_loss , weights )
    optimizer.apply_gradients( zip( grads , weights ) )
    print( tf.reduce_mean( current_loss ) )

# %%
num_epochs = 256 #@param {type: "number"}

for e in range( num_epochs ):
    for features in dataset:
        image , label = features[ 'image' ] , features[ 'label' ]
        train_step( model , image , tf.one_hot( label , depth=3 ) )
# Out:
# tf.Tensor(2.4439344, shape=(), dtype=float32)
# tf.Tensor(2.3040075, shape=(), dtype=float32)
# tf.Tensor(1.9891367, shape=(), dtype=float32)
# tf.Tensor(5.089348, shape=(), dtype=float32)
# tf.Tensor(2.1064472, shape=(), dtype=float32)
# tf.Tensor(2.673522, shape=(), dtype=float32)
# tf.Tensor(10.577499, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(7.051667, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(10.07381, shape=(), dtype=float32)
# tf.Tensor(4.5332146, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(10.577499, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(5.036905, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(10.07381, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(11.081191, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(9.570119, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(5.3726983, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066428, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(5.540595, shape=(), dtype=float32)
# tf.Tensor(10.5775, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(7.051667, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(10.5775, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(10.07381, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(9.066428, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(12.088572, shape=(), dtype=float32)
# tf.Tensor(10.745397, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.570119, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(12.088572, shape=(), dtype=float32)
# tf.Tensor(11.584881, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(10.07381, shape=(), dtype=float32)
# tf.Tensor(9.570119, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(9.066428, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(1.1920929e-07, shape=(), dtype=float32)
# tf.Tensor(9.066428, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(4.5332146, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(9.570119, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066428, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.570119, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.570119, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.570119, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(16.118095, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.066428, shape=(), dtype=float32)
# tf.Tensor(7.051667, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(10.07381, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(10.577499, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(10.577499, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(9.570119, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066428, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(5.3726983, shape=(), dtype=float32)
# tf.Tensor(7.051667, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(10.07381, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(5.540595, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(10.07381, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(5.036905, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(11.584881, shape=(), dtype=float32)
# tf.Tensor(10.07381, shape=(), dtype=float32)
# tf.Tensor(16.118095, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(10.577499, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(7.5553575, shape=(), dtype=float32)
# tf.Tensor(7.051667, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(10.577499, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(5.036905, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(4.5332146, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(9.57012, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066428, shape=(), dtype=float32)
# tf.Tensor(6.044286, shape=(), dtype=float32)
# tf.Tensor(10.577499, shape=(), dtype=float32)
# tf.Tensor(7.0516667, shape=(), dtype=float32)
# tf.Tensor(11.08119, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(10.745397, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(12.088572, shape=(), dtype=float32)
# tf.Tensor(7.555357, shape=(), dtype=float32)
# tf.Tensor(6.5479765, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(5.036905, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(8.059048, shape=(), dtype=float32)
# tf.Tensor(5.540595, shape=(), dtype=float32)
# tf.Tensor(8.562738, shape=(), dtype=float32)
# tf.Tensor(9.066429, shape=(), dtype=float32)
